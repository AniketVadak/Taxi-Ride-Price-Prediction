# %% [markdown]
# data cleaninig

# %%
import numpy as num
import pandas as pd
import matplotlib.pyplot
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\admin\Documents\taxi_trip_pricing.csv")

# %%
df.head()
# Out:
#    Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0             19.35     Morning     Weekday              3.0
# 1             47.59   Afternoon     Weekday              1.0
# 2             36.87     Evening     Weekend              1.0
# 3             30.33     Evening     Weekday              4.0
# 4               NaN     Evening     Weekday              3.0
#
#   Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                Low   Clear       3.56         0.80             0.32
# 1               High   Clear        NaN         0.62             0.43
# 2               High   Clear       2.70         1.21             0.15
# 3                Low     NaN       3.48         0.51             0.15
# 4               High   Clear       2.93         0.63             0.32
#
#    Trip_Duration_Minutes  Trip_Price
# 0                  53.82     36.2624
# 1                  40.57         NaN
# 2                  37.27     52.9032
# ...

# %%
df.isnull().sum()
# Out:
# Trip_Distance_km         50
# Time_of_Day              50
# Day_of_Week              50
# Passenger_Count          50
# Traffic_Conditions       50
# Weather                  50
# Base_Fare                50
# Per_Km_Rate              50
# Per_Minute_Rate          50
# Trip_Duration_Minutes    50
# Trip_Price               49
# dtype: int64

# %%
cf=df.copy()
cf
# Out:
#      Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0               19.35     Morning     Weekday              3.0
# 1               47.59   Afternoon     Weekday              1.0
# 2               36.87     Evening     Weekend              1.0
# 3               30.33     Evening     Weekday              4.0
# 4                 NaN     Evening     Weekday              3.0
# ..                ...         ...         ...              ...
# 995              5.49   Afternoon     Weekend              4.0
# 996             45.95       Night     Weekday              4.0
# 997              7.70     Morning     Weekday              3.0
# 998             47.56     Morning     Weekday              1.0
# 999             22.85     Morning     Weekend              3.0
#
#     Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                  Low   Clear       3.56         0.80             0.32
# ...

# %%
df[df.notnull()]
# Out:
#      Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0               19.35     Morning     Weekday              3.0
# 1               47.59   Afternoon     Weekday              1.0
# 2               36.87     Evening     Weekend              1.0
# 3               30.33     Evening     Weekday              4.0
# 4                 NaN     Evening     Weekday              3.0
# ..                ...         ...         ...              ...
# 995              5.49   Afternoon     Weekend              4.0
# 996             45.95       Night     Weekday              4.0
# 997              7.70     Morning     Weekday              3.0
# 998             47.56     Morning     Weekday              1.0
# 999             22.85     Morning     Weekend              3.0
#
#     Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                  Low   Clear       3.56         0.80             0.32
# ...

# %%
df["Time_of_Day"].unique()
# Out:
# array(['Morning', 'Afternoon', 'Evening', 'Night', nan], dtype=object)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Trip_Distance_km         0
# Time_of_Day              0
# Day_of_Week              0
# Passenger_Count          0
# Traffic_Conditions       0
# Weather                  0
# Base_Fare                0
# Per_Km_Rate              0
# Per_Minute_Rate          0
# Trip_Duration_Minutes    0
# Trip_Price               0
# dtype: int64

# %% [markdown]
# LabelEncoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
le.fit(df["Time_of_Day"])
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['Afternoon', 'Evening', 'Morning', 'Night'], dtype=object)

# %%
df["Time_of_Day"]=le.transform(df["Time_of_Day"])

# %%
df["Time_of_Day"]
# Out:
# 0      2
# 2      1
# 5      0
# 12     3
# 14     1
#       ..
# 990    1
# 992    0
# 994    1
# 995    0
# 998    2
# Name: Time_of_Day, Length: 562, dtype: int32

# %%
df["Time_of_Day"].unique
# Out:
# <bound method Series.unique of 0      2
# 2      1
# 5      0
# 12     3
# 14     1
#       ..
# 990    1
# 992    0
# 994    1
# 995    0
# 998    2
# Name: Time_of_Day, Length: 562, dtype: int32>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 562 entries, 0 to 998
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Trip_Distance_km       562 non-null    float64
#  1   Time_of_Day            562 non-null    int32
#  2   Day_of_Week            562 non-null    object
#  3   Passenger_Count        562 non-null    float64
#  4   Traffic_Conditions     562 non-null    object
#  5   Weather                562 non-null    object
#  6   Base_Fare              562 non-null    float64
#  7   Per_Km_Rate            562 non-null    float64
#  8   Per_Minute_Rate        562 non-null    float64
#  9   Trip_Duration_Minutes  562 non-null    float64
#  10  Trip_Price             562 non-null    float64
# dtypes: float64(7), int32(1), object(3)
# memory usage: 50.5+ KB

# %%
cols=["Day_of_Week","Traffic_Conditions","Weather"]
for i in cols:
    le.fit(df[i])
    print(le.classes_)
    df[i]=le.transform(df[i])
# Out:
# ['Weekday' 'Weekend']
# ['High' 'Low' 'Medium']
# ['Clear' 'Rain' 'Snow']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 562 entries, 0 to 998
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Trip_Distance_km       562 non-null    float64
#  1   Time_of_Day            562 non-null    int32
#  2   Day_of_Week            562 non-null    int32
#  3   Passenger_Count        562 non-null    float64
#  4   Traffic_Conditions     562 non-null    int32
#  5   Weather                562 non-null    int32
#  6   Base_Fare              562 non-null    float64
#  7   Per_Km_Rate            562 non-null    float64
#  8   Per_Minute_Rate        562 non-null    float64
#  9   Trip_Duration_Minutes  562 non-null    float64
#  10  Trip_Price             562 non-null    float64
# dtypes: float64(7), int32(4)
# memory usage: 43.9 KB

# %%
df.columns
# Out:
# Index(['Trip_Distance_km', 'Time_of_Day', 'Day_of_Week', 'Passenger_Count',
#        'Traffic_Conditions', 'Weather', 'Base_Fare', 'Per_Km_Rate',
#        'Per_Minute_Rate', 'Trip_Duration_Minutes', 'Trip_Price'],
#       dtype='object')

# %%
sns.pairplot(data=df)

# %% [markdown]
# spliting data into traing  testing data

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.iloc[:,:-1]
y=df["Trip_Price"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %% [markdown]
# RandomForestRegressor model

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
model.score(x_test,y_test)*100,model.score(x_train,y_train)*100
# Out:
# (96.42845004431938, 99.26017500043875)

# %%
model.predict([[47.56,2,0,1.0,1,0,2.67,0.82,0.17,114.94]])
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([63.090082])

# %%
model.predict(df.iloc[:5,:-1].values.tolist())
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([35.032561, 56.04967 , 60.112487, 90.888343, 30.845759])

# %%
df.iloc[4:5,:]
# Out:
#     Trip_Distance_km  Time_of_Day  Day_of_Week  Passenger_Count  \
# 14              9.91            1            0              2.0
#
#     Traffic_Conditions  Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 14                   0        0       2.32         1.26             0.34
#
#     Trip_Duration_Minutes  Trip_Price
# 14                  41.72     28.9914

# %%
df.shape
# Out:
# (562, 11)

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'n_estimators': [100, 200, 300],        
    'max_depth': [None, 10, 20, 30],       
    'min_samples_split': [2, 5, 10],        
    'min_samples_leaf': [1, 2, 4],         
    'max_features': ['auto', 'sqrt', 'log2']
}

# GridSearchCV setup
grid_search = GridSearchCV(estimator=model,
                           param_grid=param_grid,
                           cv=5,                      
                           n_jobs=-1,                 
                           verbose=2,                  
                           scoring='r2')            

grid_search.fit(x_train, y_train)

print("Best Parameters:\n", grid_search.best_params_)
best_model = grid_search.best_estimator_

# Predict and evaluate
predictions = best_model.predict(x_test)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 540 fits failed out of a total of 1620.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 387 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\admin\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
# ...

# %%
model.predict([[47.56,2,0,1.0,1,0,2.67,0.82,0.17,114.94]])
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([63.090082])

# %%
import pickle

# %%
with open("fare_model.pkl", "wb") as f:
    pickle.dump(model, f)

# %%
df
# Out:
#      Trip_Distance_km  Time_of_Day  Day_of_Week  Passenger_Count  \
# 0               19.35            2            0              3.0
# 2               36.87            1            1              1.0
# 5                8.64            0            1              2.0
# 12              41.79            3            1              3.0
# 14               9.91            1            0              2.0
# ..                ...          ...          ...              ...
# 990             40.17            1            0              3.0
# 992             14.34            0            0              1.0
# 994             18.69            1            0              3.0
# 995              5.49            0            1              4.0
# 998             47.56            2            0              1.0
#
#      Traffic_Conditions  Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                     1        0       3.56         0.80             0.32
# ...

# %%
#moning =2,evening=1,night=3,aftenoon=0
#weekend=1,weekday=0
#high=0,low=1,medium=2
#clear=0,rain=1,snow

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
MSE=mean_squared_error(y_test,model.predict(x_test))

# %%
MSE
# Out:
# 46.840575324678625

# %%
r2=r2_score(y_test,model.predict(x_test))

# %%
r2
# Out:
# 0.9642845004431938
